# %% [markdown]
# <a href="https://colab.research.google.com/github/groda/big_data/blob/master/mapreduce_with_bash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mapreduce with `bash`
#
# In this notebook we're going to use `bash` to write a mapper and a reducer to count words in a file. This example illustrates the main features of Hadoop's MapReduce framework.

# %% [markdown]
# # Table of contents
# - [Preamble: install Hadoop](#install_hadoop)
# - [What is MapReduce?](#mapreduce)
# - [The mapper](#mapper)
#     - [Test the mapper](#testmapper)
# - [Hadoop it up](#hadoop)
#     - [What is Hadoop Streaming?](#hadoopstreaming)
#     - [List your Hadoop directory](#hdfs_ls)
#     - [Test MapReduce with a dummy reducer](#dummyreducer)
#     - [Shuffling and sorting](#shuffling&sorting)
# - [The reducer](#reducer)
#     - [Test and run](#run)
# - [Run a mapreduce job with more data](#moredata)
#     - [Sort the output with `sort`](#sortoutput)
#     - [Sort the output with another MapReduce job](#sortoutputMR)
#     - [Configure sort with `KeyFieldBasedComparator`](#KeyFieldBasedComparator)
#     - [Specifying Configuration Variables with the -D Option](#configuration_variables)
#     - [What is word count useful for?](#wordcount)

# %% [markdown]
# ## Preamble: install Hadoop<a name="install_hadoop"></a>
#
# The Hadoop binaries can be found on the Hadoop site https://hadoop.apache.org/releases.html.
#
# The last Hadoop release as of April 2026 is [`3.5.0`](https://hadoop.apache.org/docs/r3.5.0/).
#
# After downloading the binaries we need to uncompress the archive, set the `HADOOP_HOME` environment variable, and add Hadoop's `bin` directory to our `PATH`.

# %%
import os

VERSION='3.5.0'
FILENAME=f"hadoop-{VERSION}.tar.gz"

# Download the archive if it hasn't been already
if not os.path.exists(FILENAME):
  # !curl -o $FILENAME https://dlcdn.apache.org/hadoop/common/hadoop-{VERSION}/hadoop-{VERSION}.tar.gz
  print(f"Downloaded {FILENAME}")
else:
  print(f"{FILENAME} already exists, skipping download.")

# Uncompress the archive if it hasn't been already
if not os.path.exists(f"hadoop-{VERSION}"):
  # !tar -xzf $FILENAME
  print(f"Extracted {FILENAME}")
else:
  print(f"Directory hadoop-{VERSION} already exists, skipping extraction.")

# Set HADOOP_HOME and add to PATH
os.environ['HADOOP_HOME'] = os.path.abspath(f"hadoop-{VERSION}")
os.environ['PATH'] = f"{os.environ['PATH']}:{os.environ['HADOOP_HOME']}/bin"

print(f"HADOOP_HOME is set to: {os.environ['HADOOP_HOME']}")
print("Hadoop's bin directory added to PATH.")
# Out:
# hadoop-3.5.0.tar.gz already exists, skipping download.
# Directory hadoop-3.5.0 already exists, skipping extraction.
# HADOOP_HOME is set to: /content/hadoop-3.5.0
# Hadoop's bin directory added to PATH.

# %% [markdown]
# One last thing: since Hadoop runs on Java Virtual Machines, we need to have Java and set the environment variable `JAVA_HOME`.
#
# The latest Hadoop version `3.5.0` _requires_ Java 17 for the server and supports Java 17 and 21 on the client side (see https://hadoop.apache.org/docs/r3.5.0).
#
# In Colab Java is pre-installed (and currently it's the 17 version), so we just need to find its path and set the `JAVA_HOME` environment variable.

# %%
# !java --version
# Out:
# openjdk 17.0.18 2026-01-20
# OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-122.04.1, mixed mode, sharing)

# %%
import os
import subprocess

# 1. Trust the environment variable first (GitHub Runner sets this to 17)
java_home = os.environ.get('JAVA_HOME')

# 2. If JAVA_HOME isn't set, or we are in Colab, find the active 'java' binary
if not java_home:
    try:
        # 'which java' finds the version currently first in your PATH
        path_to_java = subprocess.check_output(['which', 'java']).decode().strip()
        # Resolve symlinks to get the actual installation folder
        real_path = os.path.realpath(path_to_java)
        java_home = os.path.dirname(os.path.dirname(real_path))
    except:
        java_home = "/usr/lib/jvm/java-17-openjdk-amd64" # Colab Fallback

os.environ['JAVA_HOME'] = java_home


# 1. Get the path we know is correct (Java 17)
# On GitHub, this is already /opt/hostedtoolcache/...
# On Colab, this might be /usr/lib/jvm/java-17-openjdk-amd64
java_17_path = os.environ.get('JAVA_HOME')

# 2. Force it into the environment and the PATH
if java_17_path:
    os.environ['JAVA_HOME'] = java_17_path
    # Prepend Java 17 to PATH so '%%bash' finds it before Java 11
    # (this is needed for running the notebook with Github actions)
    os.environ['PATH'] = f"{java_17_path}/bin:" + os.environ['PATH']

# Final Check
print(f"Final JAVA_HOME: {os.environ['JAVA_HOME']}")
version = subprocess.check_output(['java', '-version'], stderr=subprocess.STDOUT).decode()
print(f"Active Version Check:\n{version}")
# Out:
# Final JAVA_HOME: /usr/lib/jvm/java-17-openjdk-amd64
# Active Version Check:
# openjdk version "17.0.18" 2026-01-20
# OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-122.04.1, mixed mode, sharing)

# %% [markdown]
# Now that `JAVA_HOME` is set, let's try checking the Hadoop version.

# %%
# !hadoop version
# Out:
# Hadoop 3.5.0
# Source code repository https://github.com/apache/hadoop.git -r dbcc7cd797100e6b32cd84f85b53a5193a5f9af0
# Compiled by cnauroth on 2026-03-24T16:56Z
# Compiled on platform linux-x86_64
# Compiled with protoc 3.25.5
# From source with checksum 64582ed0a62a169c39a19c734a8f33b5
# This command was run using /content/hadoop-3.5.0/share/hadoop/common/hadoop-common-3.5.0.jar

# %% [markdown]
# ## What is MapReduce? <a name="mapreduce"></a>
#
# MapReduce is a computing paradigm designed to allow parallel distributed processing of massive amounts of data.
#
# Data is split across several computer nodes, where it is processed by one or more _mappers_. The results emitted by the mappers are first sorted and then passed to one or more _reducers_ that process and combine the data to return the final result.
#
# ![Map & Reduce](mapreduce.png)
#   With [Hadoop Streaming](https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html) it is possible to use any programming language to define a mapper and/or a reducer.

# %% [markdown]
# In this tutorial we are going to use the streaming library and code both mapper and reducer in the Unix `bash` scripting language ([official documentation](https://www.gnu.org/software/bash/manual/html_node/index.html)).

# %% [markdown]
# ## The mapper <a name="mapper"></a>
# Let's write a mapper script called `map.sh`. The mapper splits each input line into words and for each word it outputs a line containing the word and `1` separated by a tab.
#
# Example: for the input
# <html>
# <pre>
# apple orange
# banana apple peach
# </pre>
# </html>
#
# `map.sh` outputs:
# <html>
# <pre>
# apple   1
# orange  1
# banana  1
# apple  1
# peach  1
# </pre>
# </html>
#
#
# The <a href="https://ipython.readthedocs.io/en/stable/interactive/magics.html">_cell magic_</a> [`%%writefile`](https://ipython.readthedocs.io/en/stable/interactive/magics.html#cellmagic-writefile) allows us to write the contents of the cell to a file.

# %%
# %%writefile map.sh
# #!/bin/bash
#
# # Disable globbing to prevent unintended filename expansion
# set -f
#
# while read line
# do
#   # Use IFS to correctly split words and prevent globbing
#   # Using a subshell to localize IFS change
#   (IFS=$' \t\n' read -r -a words <<< "$line"
#   for word in "${words[@]}"
#   do
#     if [ -n "$word" ]
#     then
#       echo -e "${word}\t1"
#     fi
#   done)
# done
# Out:
# Overwriting map.sh

# %% [markdown]
# After running the cell above, you should have a new file `map.sh` in your current directory.
# The file can be seen in the left panel of JupyterLab or by using a list command on the bash command-line.
#
# **Note:** you can execute a single bash command in a Jupyter notebook cell by prepending an exclamation point to the command.

# %%
# !ls -hl map.sh
# Out:
# -rwx--x--x 1 root root 358 Apr 10 20:36 map.sh

# %% [markdown]
# ### Test the mapper <a name="testmapper"></a>
# We're going to test the mapper on on the command line with a small text file `fruits.txt` by first creating the text file.
# In this file `apple` for instance appears two times, that's what we want our mapreduce job to compute.

# %%
# %%writefile fruits.txt
# apple banana
# peach orange peach peach
# pineapple peach apple
# Out:
# Overwriting fruits.txt

# %% [markdown]
# Show the contents of `fruits.txt`.

# %%
# !cat fruits.txt
# Out:
# apple banana
# peach orange peach peach
# pineapple peach apple

# %% [markdown]
# Test the mapper

# %%
# !cat fruits.txt|./map.sh
# Out:
# apple	1
# banana	1
# peach	1
# orange	1
# peach	1
# peach	1
# pineapple	1
# peach	1
# apple	1

# %% [markdown]
# If the script `map.sh` does not have the executable bit set, you need to set the correct permissions.

# %%
# !chmod 700 map.sh

# %%
# !cat fruits.txt|./map.sh
# Out:
# apple	1
# banana	1
# peach	1
# orange	1
# peach	1
# peach	1
# pineapple	1
# peach	1
# apple	1

# %% [markdown]
# ## Hadoop it up <a name="hadoop"></a>
# Let us now run a MapReduce job with Hadoop Streaming.

# %% [markdown]
# ### What is Hadoop Streaming <a name="hadoopstreaming"></a>
#
# Hadoop Streaming is a library included in the Hadoop distribution that enables you to develop MapReduce executables in languages other than Java.
#
# Mapper and/or reducer can be any sort of executables that read the input from stdin and emit the output to stdout. By default, input is read line by line and the prefix of a line up to the first tab character is the key; the rest of the line (excluding the tab character) will be the value.
#
# If there is no tab character in the line, then the entire line is considered as key and the value is null. The default input format is specified in the class `TextInputFormat` (see the [API documentation](https://hadoop.apache.org/docs/stable/api/org/apache/hadoop/mapred/TextInputFormat.html)) but this can can be customized for instance by defining another field separator (see the [Hadoop Streaming documentation](https://hadoop.apache.org/docs/stable/hadoop-streaming/HadoopStreaming.html#Customizing_How_Lines_are_Split_into_KeyValue_Pairs).
#
# This is an example of MapReduce streaming invocation syntax:
# <html>
# <pre>
#     mapred streaming \
#       -input myInputDirs \
#       -output myOutputDir \
#       -mapper /bin/cat \
#       -reducer /usr/bin/wc
# </pre>
# </html>
#
# You can find the full official documentation for Hadoop Streaming from Apache Hadoop here: [https://hadoop.apache.org/docs/stable/hadoop-streaming/HadoopStreaming.html](https://hadoop.apache.org/docs/stable/hadoop-streaming/HadoopStreaming.html).
#
# All options for the Hadoop Streaming command are described here: [Streaming Command Options](https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html#Streaming_Command_Options) and can be listed with the command

# %%
# !mapred streaming --help
# Out:
# Usage: $HADOOP_HOME/bin/hadoop jar hadoop-streaming.jar [options]
# Options:
#   -input          <path> DFS input file(s) for the Map step.
#   -output         <path> DFS output directory for the Reduce step.
#   -mapper         <cmd|JavaClassName> Optional. Command to be run as mapper.
#   -combiner       <cmd|JavaClassName> Optional. Command to be run as combiner.
#   -reducer        <cmd|JavaClassName> Optional. Command to be run as reducer.
#   -file           <file> Optional. File/dir to be shipped in the Job jar file.
#                   Deprecated. Use generic option "-files" instead.
#   -inputformat    <TextInputFormat(default)|SequenceFileAsTextInputFormat|JavaClassName>
#                   Optional. The input format class.
#   -outputformat   <TextOutputFormat(default)|JavaClassName>
#                   Optional. The output format class.
#   -partitioner    <JavaClassName>  Optional. The partitioner class.
#   -numReduceTasks <num> Optional. Number of reduce tasks.
#   -inputreader    <spec> Optional. Input recordreader spec.
#   -cmdenv         <n>=<v> Optional. Pass env.var to streaming commands.
#   -mapdebug       <cmd> Optional. To run this script when a map task fails.
#   -reducedebug    <cmd> Optional. To run this script when a reduce task fails.
#   -io             <identifier> Optional. Format to use for input to and output
#                   from mapper/reducer commands
#   -lazyOutput     Optional. Lazily create Output.
#   -background     Optional. Submit the job and don't wait till it completes.
#   -verbose        Optional. Print verbose output.
#   -info           Optional. Print detailed usage.
#   -help           Optional. Print help message.
#
# Generic options supported are:
# -conf <configuration file>        specify an application configuration file
# -D <property=value>               define a value for a given property
# -fs <file:///|hdfs://namenode:port> specify default filesystem URL to use, overrides 'fs.defaultFS' property from configurations.
# -jt <local|resourcemanager:port>  specify a ResourceManager
# -files <file1,...>                specify a comma-separated list of files to be copied to the map reduce cluster
# -libjars <jar1,...>               specify a comma-separated list of jar files to be included in the classpath
# -archives <archive1,...>          specify a comma-separated list of archives to be unarchived on the compute machines
#
# The general command line syntax is:
# command [genericOptions] [commandOptions]
#
#
# For more details about these options:
# Use $HADOOP_HOME/bin/hadoop jar hadoop-streaming.jar -info

# %% [markdown]
# Now in order to run a MapReduce job that we need to "upload" the input file to the Hadoop file system.

# %% [markdown]
# ### List your Hadoop directory <a name="hdfs_ls"></a>
#
# With the command `hdfs dfs -l` you can view the content of your HDFS home directory.
#
# `hdfs dfs` you can run a filesystem command on the Hadoop fileystem. The complete list of commands can be found in the [System Shell Guide](https://hadoop.apache.org/docs/stable/hadoop-project-dist/hadoop-hdfs/HDFSCommands.html#dfs).

# %%
# !hdfs dfs -ls
# Out:
# Found 11 items
# drwxr-xr-x   - root root       4096 2026-04-02 13:31 .config
# -rwx------   1 root root         95 2026-04-10 19:26 debug_map_input.sh
# -rw-r--r--   1 root root         60 2026-04-10 20:36 fruits.txt
# drwxr-xr-x   - 1001 1002       4096 2026-03-24 17:31 hadoop-3.5.0
# -rw-r--r--   1 root root  581280703 2026-04-10 19:08 hadoop-3.5.0.tar.gz
# -rwx------   1 root root        358 2026-04-10 20:36 map.sh
# -rw-r--r--   1 root root     737631 2026-04-10 19:35 moby_dick.txt
# -rwx--x--x   1 root root        397 2026-04-10 19:43 reduce.sh
# drwxr-xr-x   - root root       4096 2026-04-02 13:31 sample_data
# -rwxr-xr-x   1 root root        194 2026-04-10 19:46 swap_keyval.sh
# drwxr-xr-x   - root root       4096 2026-04-10 19:46 wordcount

# %% [markdown]
# ### A note on HDFS
#
# When you install Hadoop, it comes with a 'fake' `hdfs` command that, in this tutorial, runs on the regular local filesystem. Installing a real HDFS is beyond the scope of this tutorial. For the learner, this difference is negligible, as the commands are the same.
#
# ### Would it make sense to install HDFS on a single machine?
# While HDFS is primarily designed for distributed storage across a cluster of commodity machines, even on a single machine, one could theoretically find some benefits from a pseudo-distributed or even a real HDFS setup.
#
# For example:
#
# - Managing very large files: HDFS is excellent at handling files that are larger than the capacity of a single disk, splitting them into blocks. On a massive single server, you might still have a need to manage files exceeding individual disk limits.
# - Fault tolerance: HDFS provides data replication, meaning data can be stored multiple times across different physical drives (or even partitions) on the same large machine, offering a level of fault tolerance even without multiple independent nodes.
# - Scalability (internal): Even on a single node, HDFS mechanisms for managing metadata and block placement can provide a more organized way to handle extremely large datasets than a standard filesystem.
#
# However, the main advantage of HDFS comes from its ability to distribute data and computation across many machines, enabling massive parallel processing that a single machine, no matter how large, cannot achieve. For the purpose of this tutorial, which focuses on the MapReduce paradigm using streaming, the underlying filesystem's distributed nature isn't the primary learning objective. The 'fake' HDFS operating on the local filesystem allows us to use the `hadoop` or `hdfs dfs` commands and experience the MapReduce workflow without the overhead of setting up a full-blown distributed system.

# %% [markdown]
# Now create a directory `wordcount` with a subdirectory `input` on the Hadoop filesystem.

# %%
# %%bash
# hdfs dfs -mkdir -p wordcount

# %% [markdown]
# Copy the file fruits.txt to Hadoop in the folder `wordcount/input`.
#
# Why do we need this step? Because the file `fruits.txt` needs to reside on the Hadoop filesystem in order to enjoy of all of the features of Hadoop (data partitioning, distributed processing, fault tolerance).

# %%
# %%bash
# hdfs dfs -rm -r wordcount/input 2>/dev/null
# hdfs dfs -mkdir wordcount/input
# hdfs dfs -put fruits.txt wordcount/input
# Out:
# Deleted wordcount/input

# %% [markdown]
# Let's check if the file is there now.
#
# **Note:** it is convenient use the option `-h` for `ls` to show file sizes in human-readable form (showing sizes in Kilobytes, Megabytes, Gigabytes, etc.)

# %%
# !hdfs dfs -ls -h -R wordcount/input
# Out:
# -rw-r--r--   1 root root         60 2026-04-10 20:36 wordcount/input/fruits.txt

# %% [markdown]
# ### Test MapReduce with a dummy reducer <a name="dummyreducer"></a>
#
# Let's try to run the mapper using a dummy reducer (`/bin/cat` does nothing else than echoing the data it receives).
#
# **Warning:** mapreduce tends to produce a verbose output, so be ready to see a long output. What you should look for is a message of the kind <html><pre>"INFO mapreduce.Job: Job ... completed successfully"</pre></html>
#
# **Note:** at the beginning of next cell you'll see a command `hadoop fs -rmr wordcount/output 2>/dev/null`. This is needed because when you run a job several times mapreduce will give an error if you try to overwrite the same output directory (according to Hadoop's principle _write once, read many_, output data can not be overwritten).

# %%
# %%bash
# hdfs dfs -rm -r wordcount/output 2>/dev/null
# mapred streaming \
#   -files map.sh \
#   -input wordcount/input \
#   -output wordcount/output \
#   -mapper map.sh \
#   -reducer /bin/cat
# Out:
# Deleted wordcount/output
# 2026-04-10 20:36:28,657 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:36:29,022 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-04-10 20:36:29,046 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-04-10 20:36:29,398 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1055154046_0001
# 2026-04-10 20:36:29,400 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-04-10 20:36:29,795 INFO mapred.LocalDistributedCacheManager: Localized file:/content/map.sh as file:/tmp/hadoop-root/mapred/local/job_local1055154046_0001_1d57f934-e690-4b19-86ef-019b541ef269/map.sh
# 2026-04-10 20:36:29,936 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2026-04-10 20:36:29,937 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2026-04-10 20:36:29,938 INFO mapreduce.Job: Running job: job_local1055154046_0001
# 2026-04-10 20:36:29,943 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2026-04-10 20:36:29,949 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:36:29,954 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:36:30,022 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2026-04-10 20:36:30,030 INFO mapred.LocalJobRunner: Starting task: attempt_local1055154046_0001_m_000000_0
# 2026-04-10 20:36:30,084 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:36:30,084 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:36:30,109 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:36:30,124 INFO mapred.MapTask: Processing split: file:/content/wordcount/input/fruits.txt:0+60
# 2026-04-10 20:36:30,145 INFO mapred.MapTask: numReduceTasks: 1
# 2026-04-10 20:36:30,274 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2026-04-10 20:36:30,275 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2026-04-10 20:36:30,275 INFO mapred.MapTask: soft limit at 83886080
# 2026-04-10 20:36:30,275 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2026-04-10 20:36:30,276 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2026-04-10 20:36:30,279 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2026-04-10 20:36:30,291 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./map.sh]
# 2026-04-10 20:36:30,300 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:36:30,303 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:36:30,303 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2026-04-10 20:36:30,304 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2026-04-10 20:36:30,306 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:36:30,306 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:36:30,308 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2026-04-10 20:36:30,309 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:36:30,309 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:36:30,309 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:36:30,310 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:36:30,311 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:36:30,374 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:36:30,378 INFO streaming.PipeMapRed: Records R/W=3/1
# 2026-04-10 20:36:30,380 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:36:30,382 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:36:30,385 INFO mapred.LocalJobRunner:
# 2026-04-10 20:36:30,387 INFO mapred.MapTask: Starting flush of map output
# 2026-04-10 20:36:30,387 INFO mapred.MapTask: Spilling map output
# 2026-04-10 20:36:30,387 INFO mapred.MapTask: bufstart = 0; bufend = 78; bufvoid = 104857600
# 2026-04-10 20:36:30,403 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214364(104857456); length = 33/6553600
# 2026-04-10 20:36:30,423 INFO mapred.MapTask: Finished spill 0
# 2026-04-10 20:36:30,441 INFO mapred.Task: Task:attempt_local1055154046_0001_m_000000_0 is done. And is in the process of committing
# 2026-04-10 20:36:30,447 INFO mapred.LocalJobRunner: Records R/W=3/1
# 2026-04-10 20:36:30,448 INFO mapred.Task: Task 'attempt_local1055154046_0001_m_000000_0' done.
# 2026-04-10 20:36:30,462 INFO mapred.Task: Final Counters for attempt_local1055154046_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=145602
# 		FILE: Number of bytes written=885355
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=3
# 		Map output records=9
# 		Map output bytes=78
# 		Map output materialized bytes=102
# 		Input split bytes=92
# 		Combine input records=0
# 		Spilled Records=9
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=18
# 		Total committed heap usage (bytes)=281018368
# 	File Input Format Counters
# 		Bytes Read=76
# 2026-04-10 20:36:30,463 INFO mapred.LocalJobRunner: Finishing task: attempt_local1055154046_0001_m_000000_0
# 2026-04-10 20:36:30,463 INFO mapred.LocalJobRunner: map task executor complete.
# 2026-04-10 20:36:30,471 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2026-04-10 20:36:30,471 INFO mapred.LocalJobRunner: Starting task: attempt_local1055154046_0001_r_000000_0
# 2026-04-10 20:36:30,485 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:36:30,485 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:36:30,486 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:36:30,495 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@1507a10b
# 2026-04-10 20:36:30,497 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:36:30,539 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2026-04-10 20:36:30,544 INFO reduce.EventFetcher: attempt_local1055154046_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2026-04-10 20:36:30,610 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1055154046_0001_m_000000_0 decomp: 98 len: 102 to MEMORY
# 2026-04-10 20:36:30,618 INFO reduce.InMemoryMapOutput: Read 98 bytes from map-output for attempt_local1055154046_0001_m_000000_0
# 2026-04-10 20:36:30,629 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 98, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->98
# 2026-04-10 20:36:30,648 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2026-04-10 20:36:30,650 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:36:30,650 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2026-04-10 20:36:30,660 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:36:30,664 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 90 bytes
# 2026-04-10 20:36:30,666 INFO reduce.MergeManagerImpl: Merged 1 segments, 98 bytes to disk to satisfy reduce memory limit
# 2026-04-10 20:36:30,671 INFO reduce.MergeManagerImpl: Merging 1 files, 102 bytes from disk
# 2026-04-10 20:36:30,674 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2026-04-10 20:36:30,674 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:36:30,677 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 90 bytes
# 2026-04-10 20:36:30,678 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:36:30,680 INFO streaming.PipeMapRed: PipeMapRed exec [/bin/cat]
# 2026-04-10 20:36:30,684 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:36:30,685 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2026-04-10 20:36:30,685 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:36:30,686 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:36:30,686 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:36:30,688 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:36:30,688 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:36:30,689 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:36:30,690 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:36:30,690 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2026-04-10 20:36:30,691 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:36:30,716 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:36:30,718 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:36:30,720 INFO streaming.PipeMapRed: Records R/W=9/1
# 2026-04-10 20:36:30,721 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:36:30,722 INFO mapred.Task: Task:attempt_local1055154046_0001_r_000000_0 is done. And is in the process of committing
# 2026-04-10 20:36:30,725 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:36:30,726 INFO mapred.Task: Task attempt_local1055154046_0001_r_000000_0 is allowed to commit now
# 2026-04-10 20:36:30,732 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1055154046_0001_r_000000_0' to file:/content/wordcount/output
# 2026-04-10 20:36:30,734 INFO mapred.LocalJobRunner: Records R/W=9/1 > reduce
# 2026-04-10 20:36:30,734 INFO mapred.Task: Task 'attempt_local1055154046_0001_r_000000_0' done.
# 2026-04-10 20:36:30,737 INFO mapred.Task: Final Counters for attempt_local1055154046_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=145838
# 		FILE: Number of bytes written=885547
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=102
# 		Reduce input records=9
# 		Reduce output records=9
# 		Spilled Records=9
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=281018368
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=90
# 2026-04-10 20:36:30,737 INFO mapred.LocalJobRunner: Finishing task: attempt_local1055154046_0001_r_000000_0
# 2026-04-10 20:36:30,738 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2026-04-10 20:36:30,944 INFO mapreduce.Job: Job job_local1055154046_0001 running in uber mode : false
# 2026-04-10 20:36:30,946 INFO mapreduce.Job:  map 100% reduce 100%
# 2026-04-10 20:36:30,949 INFO mapreduce.Job: Job job_local1055154046_0001 completed successfully
# 2026-04-10 20:36:30,959 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=291440
# 		FILE: Number of bytes written=1770902
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=3
# 		Map output records=9
# 		Map output bytes=78
# 		Map output materialized bytes=102
# 		Input split bytes=92
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=102
# 		Reduce input records=9
# 		Reduce output records=9
# 		Spilled Records=18
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=18
# 		Total committed heap usage (bytes)=562036736
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76
# 	File Output Format Counters
# 		Bytes Written=90
# 2026-04-10 20:36:30,960 INFO streaming.StreamJob: Output directory: wordcount/output

# %% [markdown]
# The output of the mapreduce job is in the `output` subfolder of the input directory. Let's check what's inside it.

# %%
# !hdfs dfs -ls wordcount/output
# Out:
# Found 2 items
# -rw-r--r--   1 root root          0 2026-04-10 20:36 wordcount/output/_SUCCESS
# -rw-r--r--   1 root root         78 2026-04-10 20:36 wordcount/output/part-00000

# %% [markdown]
# If `output` contains a file named `_SUCCESS` that means that the mapreduce job completed successfully.
#
# **Note:** when dealing with Big Data it's always advisable to pipe the output of `cat` commands to `head` (or `tail`).

# %%
# !hdfs dfs -cat wordcount/output/part*|head
# Out:
# apple	1
# apple	1
# banana	1
# orange	1
# peach	1
# peach	1
# peach	1
# peach	1
# pineapple	1

# %% [markdown]
# We have gotten as expected all the output from the mapper. Something worth of notice is that the data outputted from the mapper _**has been sorted**_. We haven't asked for that but this step is automatically performed by the mapper as soon as the number of reducers is $\gt 0$.

# %% [markdown]
# ### Shuffling and sorting <a name="shuffling&sorting"></a>
# The following picture illustrates the concept of shuffling and sorting that is automatically performed by Hadoop after each map before passing the output to reduce. In the picture the outputs of the two mapper tasks are shown. The arrows represent shuffling and sorting done before delivering the data to one reducer (rightmost box).
# ![Shuffle & sort](shuffle_sort.png)
# The shuffling and sorting phase is often one of the most costly in a MapReduce job.
#
#
# <b>Note:</b> the job ran with two mappers because $2$ is the default number of mappers in Hadoop.

# %% [markdown]
# ## The reducer <a name="reducer"></a>
# Let's now write a reducer script called `reduce.sh`.

# %%
# %%writefile reduce.sh
# #!/bin/bash
#
# # Disable globbing to prevent unintended filename expansion
# set -f
#
# currkey=""
# currcount=0
# while IFS=$'\t' read -r key val
# do
#   if [[ "$key" == "$currkey" ]]
#   then
#       currcount=$(( currcount + val ))
#   else
#     if [ -n "$currkey" ]
#     then
#       echo -e "${currkey}\t${currcount}"
#     fi
#     currkey="$key"
#     currcount=1
#   fi
# done
# # last one
# echo -e "${currkey}\t${currcount}"
# Out:
# Overwriting reduce.sh

# %% [markdown]
# Set permission for the reducer script.

# %%
# !chmod 700 reduce.sh

# %% [markdown]
# ### Test and run <a name="run"></a>
#
# Test map and reduce on the shell

# %% [markdown]
# This is MapReduce in a nutshell: input / apply mapper / sort / apply reducer. It just runs locally.
#
# ```bash
# cat fruits.txt | ./map.sh | sort | ./reduce.sh
# ```

# %%
# !cat fruits.txt | ./map.sh | sort | ./reduce.sh
# Out:
# apple	2
# banana	1
# orange	1
# peach	4
# pineapple	1

# %% [markdown]
# Once we've made sure that the reducer script runs correctly on the shell, we can run it on the cluster. When we run MapReduce on a Hadoop cluster, the data is partitioned and mappers act on chunks of data on different nodes.

# %%
# %%bash
# hdfs dfs -rm -r wordcount/output 2>/dev/null
# mapred streaming \
#   -file map.sh \
#   -file reduce.sh \
#   -input wordcount/input \
#   -output wordcount/output \
#   -mapper map.sh \
#   -reducer reduce.sh
# Out:
# Deleted wordcount/output
# packageJobJar: [map.sh, reduce.sh] [] /tmp/streamjob17326936084831396354.jar tmpDir=null
# 2026-04-10 20:36:40,151 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 2026-04-10 20:36:41,305 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:36:41,570 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-04-10 20:36:41,595 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-04-10 20:36:41,938 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local941183677_0001
# 2026-04-10 20:36:41,939 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-04-10 20:36:42,433 INFO mapred.LocalDistributedCacheManager: Localized file:/content/map.sh as file:/tmp/hadoop-root/mapred/local/job_local941183677_0001_5b487b6f-4918-4baa-b752-8472d06b6642/map.sh
# 2026-04-10 20:36:42,470 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reduce.sh as file:/tmp/hadoop-root/mapred/local/job_local941183677_0001_0b315efe-f49d-4ac9-b0a1-d122fb925ef0/reduce.sh
# 2026-04-10 20:36:42,640 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2026-04-10 20:36:42,643 INFO mapreduce.Job: Running job: job_local941183677_0001
# 2026-04-10 20:36:42,644 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2026-04-10 20:36:42,648 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2026-04-10 20:36:42,663 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:36:42,671 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:36:42,753 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2026-04-10 20:36:42,760 INFO mapred.LocalJobRunner: Starting task: attempt_local941183677_0001_m_000000_0
# 2026-04-10 20:36:42,843 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:36:42,843 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:36:42,879 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:36:42,907 INFO mapred.MapTask: Processing split: file:/content/wordcount/input/fruits.txt:0+60
# 2026-04-10 20:36:42,938 INFO mapred.MapTask: numReduceTasks: 1
# 2026-04-10 20:36:43,083 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2026-04-10 20:36:43,083 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2026-04-10 20:36:43,084 INFO mapred.MapTask: soft limit at 83886080
# 2026-04-10 20:36:43,084 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2026-04-10 20:36:43,084 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2026-04-10 20:36:43,090 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2026-04-10 20:36:43,104 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./map.sh]
# 2026-04-10 20:36:43,122 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:36:43,123 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:36:43,124 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2026-04-10 20:36:43,124 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2026-04-10 20:36:43,131 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:36:43,132 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:36:43,139 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2026-04-10 20:36:43,140 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:36:43,140 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:36:43,143 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:36:43,144 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:36:43,145 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:36:43,226 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:36:43,235 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:36:43,235 INFO streaming.PipeMapRed: Records R/W=3/1
# 2026-04-10 20:36:43,236 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:36:43,241 INFO mapred.LocalJobRunner:
# 2026-04-10 20:36:43,241 INFO mapred.MapTask: Starting flush of map output
# 2026-04-10 20:36:43,241 INFO mapred.MapTask: Spilling map output
# 2026-04-10 20:36:43,242 INFO mapred.MapTask: bufstart = 0; bufend = 78; bufvoid = 104857600
# 2026-04-10 20:36:43,249 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26214364(104857456); length = 33/6553600
# 2026-04-10 20:36:43,272 INFO mapred.MapTask: Finished spill 0
# 2026-04-10 20:36:43,292 INFO mapred.Task: Task:attempt_local941183677_0001_m_000000_0 is done. And is in the process of committing
# 2026-04-10 20:36:43,296 INFO mapred.LocalJobRunner: Records R/W=3/1
# 2026-04-10 20:36:43,296 INFO mapred.Task: Task 'attempt_local941183677_0001_m_000000_0' done.
# 2026-04-10 20:36:43,307 INFO mapred.Task: Final Counters for attempt_local941183677_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=1681
# 		FILE: Number of bytes written=736981
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=3
# 		Map output records=9
# 		Map output bytes=78
# 		Map output materialized bytes=102
# 		Input split bytes=92
# 		Combine input records=0
# 		Spilled Records=9
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=14
# 		Total committed heap usage (bytes)=281018368
# 	File Input Format Counters
# 		Bytes Read=76
# 2026-04-10 20:36:43,307 INFO mapred.LocalJobRunner: Finishing task: attempt_local941183677_0001_m_000000_0
# 2026-04-10 20:36:43,308 INFO mapred.LocalJobRunner: map task executor complete.
# 2026-04-10 20:36:43,313 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2026-04-10 20:36:43,314 INFO mapred.LocalJobRunner: Starting task: attempt_local941183677_0001_r_000000_0
# 2026-04-10 20:36:43,326 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:36:43,326 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:36:43,327 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:36:43,332 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@574d56f7
# 2026-04-10 20:36:43,334 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:36:43,370 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2026-04-10 20:36:43,378 INFO reduce.EventFetcher: attempt_local941183677_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2026-04-10 20:36:43,465 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local941183677_0001_m_000000_0 decomp: 98 len: 102 to MEMORY
# 2026-04-10 20:36:43,473 INFO reduce.InMemoryMapOutput: Read 98 bytes from map-output for attempt_local941183677_0001_m_000000_0
# 2026-04-10 20:36:43,486 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 98, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->98
# 2026-04-10 20:36:43,501 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2026-04-10 20:36:43,503 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:36:43,504 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2026-04-10 20:36:43,518 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:36:43,526 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 90 bytes
# 2026-04-10 20:36:43,532 INFO reduce.MergeManagerImpl: Merged 1 segments, 98 bytes to disk to satisfy reduce memory limit
# 2026-04-10 20:36:43,552 INFO reduce.MergeManagerImpl: Merging 1 files, 102 bytes from disk
# 2026-04-10 20:36:43,555 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2026-04-10 20:36:43,555 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:36:43,558 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 90 bytes
# 2026-04-10 20:36:43,560 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:36:43,567 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reduce.sh]
# 2026-04-10 20:36:43,572 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:36:43,574 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2026-04-10 20:36:43,574 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:36:43,577 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:36:43,577 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:36:43,580 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:36:43,580 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:36:43,581 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:36:43,581 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:36:43,582 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2026-04-10 20:36:43,582 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:36:43,626 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:36:43,629 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:36:43,631 INFO streaming.PipeMapRed: Records R/W=9/1
# 2026-04-10 20:36:43,632 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:36:43,633 INFO mapred.Task: Task:attempt_local941183677_0001_r_000000_0 is done. And is in the process of committing
# 2026-04-10 20:36:43,637 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:36:43,638 INFO mapred.Task: Task attempt_local941183677_0001_r_000000_0 is allowed to commit now
# 2026-04-10 20:36:43,646 INFO output.FileOutputCommitter: Saved output of task 'attempt_local941183677_0001_r_000000_0' to file:/content/wordcount/output
# 2026-04-10 20:36:43,647 INFO mapred.LocalJobRunner: Records R/W=9/1 > reduce
# 2026-04-10 20:36:43,647 INFO mapred.Task: Task 'attempt_local941183677_0001_r_000000_0' done.
# 2026-04-10 20:36:43,649 INFO mapred.Task: Final Counters for attempt_local941183677_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=1917
# 		FILE: Number of bytes written=737141
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=102
# 		Reduce input records=9
# 		Reduce output records=5
# 		Spilled Records=9
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=281018368
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=58
# 2026-04-10 20:36:43,651 INFO mapred.LocalJobRunner: Finishing task: attempt_local941183677_0001_r_000000_0
# 2026-04-10 20:36:43,652 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2026-04-10 20:36:43,651 INFO mapreduce.Job: Job job_local941183677_0001 running in uber mode : false
# 2026-04-10 20:36:43,679 INFO mapreduce.Job:  map 100% reduce 100%
# 2026-04-10 20:36:43,690 INFO mapreduce.Job: Job job_local941183677_0001 completed successfully
# 2026-04-10 20:36:43,728 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=3598
# 		FILE: Number of bytes written=1474122
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=3
# 		Map output records=9
# 		Map output bytes=78
# 		Map output materialized bytes=102
# 		Input split bytes=92
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=102
# 		Reduce input records=9
# 		Reduce output records=5
# 		Spilled Records=18
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=14
# 		Total committed heap usage (bytes)=562036736
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76
# 	File Output Format Counters
# 		Bytes Written=58
# 2026-04-10 20:36:43,739 INFO streaming.StreamJob: Output directory: wordcount/output

# %% [markdown]
# Let's explain the Hadoop MapReduce job command:
#
# ```bash
# hdfs dfs -rm -r wordcount/output 2>/dev/null
# mapred streaming \
#   -file map.sh \
#   -file reduce.sh \
#   -input wordcount/input \
#   -output wordcount/output \
#   -mapper map.sh \
#   -reducer reduce.sh
# ```
#
# *   `hdfs dfs -rm -r wordcount/output 2>/dev/null`: This command first deletes the `wordcount/output` directory in HDFS if it exists. The `-rm -r` options ensure recursive deletion. `2>/dev/null` redirects any error messages (like "directory not found") to `/dev/null`, effectively suppressing them.
# *   `mapred streaming`: This is the command to invoke Hadoop Streaming, which allows you to use executables written in non-Java languages (like bash scripts here) as mappers and reducers.
# *   `-file map.sh`: This option tells Hadoop to include `map.sh` in the distributed cache, making it available to all nodes running the MapReduce job.
# *   `-file reduce.sh`: Similarly, this includes `reduce.sh` in the distributed cache.
# *   `-input wordcount/input`: Specifies the input directory in HDFS for the MapReduce job. The mappers will read data from here.
# *   `-output wordcount/output`: Specifies the output directory in HDFS where the results of the Reduce phase will be written. Hadoop requires this directory not to exist before the job starts, which is why we delete it first.
# *   `-mapper map.sh`: Designates `map.sh` as the mapper executable for the job.
# *   `-reducer reduce.sh`: Designates `reduce.sh` as the reducer executable for the job.

# %% [markdown]
# Let's check the output on the HDFS filesystem

# %%
# !hdfs dfs -cat wordcount/output/part*|head
# Out:
# apple	2
# banana	1
# orange	1
# peach	4
# pineapple	1

# %% [markdown]
# ## Run a MapReduce job with more data <a name="moredata"></a>
#
# Let's create a datafile by downloading some real data, for instance from a Web page. This example will be used to introduce some advanced configurations.
#
# Next, we download a URL with `wget` and filter out HTML tags with a `sed` regular expression.

# %% [markdown]
# Let's download another sample text file for processing.

# %%
# %%bash
# URL="https://www.gutenberg.org/files/1342/1342-0.txt"
# wget --no-clobber -qO- $URL | sed -e 's/<[^>]*>//g;s/^ //g' > moby_dick.txt
# echo "Downloaded and preprocessed moby_dick.txt"
# Out:
# Downloaded and preprocessed moby_dick.txt

# %% [markdown]
# Now, let's take a look at a few lines of the newly downloaded file using `shuf` to randomly select lines.

# %%
# !cat moby_dick.txt | shuf -n 10
# Out:
# being at home again in a day or two. Jane was already so much recovered
#
#
# Mr. Wickham began to speak on more general topics, Meryton, the
#
# of the four can come into competition with Elizabeth._
# we need not go beyond her own comparison to the art of a miniature
#
# female character.”
# have gone quite distracted. And there was my aunt, all the time I was

# %%
# !shuf -n 10 moby_dick.txt | ./map.sh |head
# Out:
# In	1
# this	1
# perturbed	1
# state	1
# of	1
# mind,	1
# with	1
# thoughts	1
# that	1
# could	1

# %% [markdown]
# As usual, with real data there's some more work to do. Here we see that the mapper script doesn't skip empty lines. Let's modify it so that empty lines are skipped.

# %%
# %%writefile map.sh
# #!/bin/bash
#
# # Disable globbing to prevent unintended filename expansion
# set -f
#
# while read line
# do
#   if [[ "$line" =~ [^[:space:]] ]]
#   then
#     # Use IFS to correctly split words and prevent globbing
#     # Using a subshell to localize IFS change
#     (IFS=$' \t\n' read -r -a words <<< "$line"
#     for word in "${words[@]}"
#     do
#       if [ -n "$word" ]
#       then
#         echo -e "${word}\t1"
#       fi
#     done)
#   fi
# done
# Out:
# Overwriting map.sh

# %% [markdown]
# **Note:** when working with real data we may still need some more preprocessing in order to remove control characters or invalid unicode.
#
# Time to run MapReduce again with this new data, but first we need to "put" the data on HDFS.

# %%
# %%bash
# hdfs dfs -rm -r wordcount/input 2>/dev/null
# hdfs dfs -put moby_dick.txt wordcount/input
# Out:
# Deleted wordcount/input

# %%
# check that the folder wordcount/input on HDFS now contains moby_dick.txt
# !hdfs dfs -ls -h wordcount/input
# Out:
# -rw-r--r--   1 root root    720.3 K 2026-04-10 20:36 wordcount/input

# %% [markdown]
# Check the reducer with `moby_dick.txt`

# %%
# !shuf -n 10 moby_dick.txt | ./map.sh | ./reduce.sh | head
# Out:
# acquaintance.	1
# The	1
# subjection	1
# in	1
# which	1
# his	1
# father	1
# had	1
# brought	1
# him	1

# %%
# %%bash
# hadoop fs -rmr wordcount/output 2>/dev/null
# mapred streaming \
#   -file map.sh \
#   -file reduce.sh \
#   -input wordcount/input \
#   -output wordcount/output \
#   -mapper map.sh \
#   -reducer reduce.sh
# Out:
# Deleted wordcount/output
# packageJobJar: [map.sh, reduce.sh] [] /tmp/streamjob12240650926329316032.jar tmpDir=null
# 2026-04-10 20:36:58,059 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 2026-04-10 20:36:59,714 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:37:00,309 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-04-10 20:37:00,373 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-04-10 20:37:01,013 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local771269508_0001
# 2026-04-10 20:37:01,019 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-04-10 20:37:01,886 INFO mapred.LocalDistributedCacheManager: Localized file:/content/map.sh as file:/tmp/hadoop-root/mapred/local/job_local771269508_0001_f23b0152-e219-438c-a845-cc904eab198e/map.sh
# 2026-04-10 20:37:01,946 INFO mapred.LocalDistributedCacheManager: Localized file:/content/reduce.sh as file:/tmp/hadoop-root/mapred/local/job_local771269508_0001_debc1d99-aebf-4341-a2ac-619381137aa4/reduce.sh
# 2026-04-10 20:37:02,284 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2026-04-10 20:37:02,290 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2026-04-10 20:37:02,292 INFO mapreduce.Job: Running job: job_local771269508_0001
# 2026-04-10 20:37:02,294 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2026-04-10 20:37:02,309 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:02,315 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:02,467 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2026-04-10 20:37:02,475 INFO mapred.LocalJobRunner: Starting task: attempt_local771269508_0001_m_000000_0
# 2026-04-10 20:37:02,556 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:02,556 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:02,595 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:37:02,612 INFO mapred.MapTask: Processing split: file:/content/wordcount/input:0+737631
# 2026-04-10 20:37:02,635 INFO mapred.MapTask: numReduceTasks: 1
# 2026-04-10 20:37:02,750 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2026-04-10 20:37:02,750 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2026-04-10 20:37:02,750 INFO mapred.MapTask: soft limit at 83886080
# 2026-04-10 20:37:02,751 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2026-04-10 20:37:02,751 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2026-04-10 20:37:02,755 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2026-04-10 20:37:02,765 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./map.sh]
# 2026-04-10 20:37:02,773 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:37:02,775 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:37:02,776 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2026-04-10 20:37:02,776 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2026-04-10 20:37:02,777 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:37:02,777 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:37:02,778 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2026-04-10 20:37:02,779 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:37:02,779 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:37:02,779 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:37:02,780 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:37:02,781 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:37:02,820 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:02,820 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:02,824 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:02,846 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:02,873 INFO streaming.PipeMapRed: Records R/W=2783/1
# 2026-04-10 20:37:03,306 INFO mapreduce.Job: Job job_local771269508_0001 running in uber mode : false
# 2026-04-10 20:37:03,310 INFO mapreduce.Job:  map 0% reduce 0%
# 2026-04-10 20:37:07,813 INFO streaming.PipeMapRed: R/W/S=10000/55809/0 in:2000=10000/5 [rec/s] out:11167=55836/5 [rec/s]
# 2026-04-10 20:37:12,873 INFO streaming.PipeMapRed: Records R/W=14537/114490
# 2026-04-10 20:37:14,118 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:37:14,118 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:37:14,124 INFO mapred.LocalJobRunner:
# 2026-04-10 20:37:14,127 INFO mapred.MapTask: Starting flush of map output
# 2026-04-10 20:37:14,127 INFO mapred.MapTask: Spilling map output
# 2026-04-10 20:37:14,127 INFO mapred.MapTask: bufstart = 0; bufend = 982518; bufvoid = 104857600
# 2026-04-10 20:37:14,149 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 25704892(102819568); length = 509505/6553600
# 2026-04-10 20:37:14,610 INFO mapred.LocalJobRunner: Records R/W=14537/114490 > sort
# 2026-04-10 20:37:15,153 INFO mapred.MapTask: Finished spill 0
# 2026-04-10 20:37:15,166 INFO mapred.Task: Task:attempt_local771269508_0001_m_000000_0 is done. And is in the process of committing
# 2026-04-10 20:37:15,172 INFO mapred.LocalJobRunner: Records R/W=14537/114490
# 2026-04-10 20:37:15,177 INFO mapred.Task: Task 'attempt_local771269508_0001_m_000000_0' done.
# 2026-04-10 20:37:15,199 INFO mapred.Task: Final Counters for attempt_local771269508_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=745099
# 		FILE: Number of bytes written=1974244
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=14537
# 		Map output records=127377
# 		Map output bytes=982518
# 		Map output materialized bytes=1237278
# 		Input split bytes=81
# 		Combine input records=0
# 		Spilled Records=127377
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=13
# 		Total committed heap usage (bytes)=281018368
# 	File Input Format Counters
# 		Bytes Read=743407
# 2026-04-10 20:37:15,199 INFO mapred.LocalJobRunner: Finishing task: attempt_local771269508_0001_m_000000_0
# 2026-04-10 20:37:15,200 INFO mapred.LocalJobRunner: map task executor complete.
# 2026-04-10 20:37:15,216 INFO mapred.LocalJobRunner: Starting task: attempt_local771269508_0001_r_000000_0
# 2026-04-10 20:37:15,218 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2026-04-10 20:37:15,243 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:15,245 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:15,249 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:37:15,260 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@697d4f5a
# 2026-04-10 20:37:15,264 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:37:15,313 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2026-04-10 20:37:15,324 INFO reduce.EventFetcher: attempt_local771269508_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2026-04-10 20:37:15,344 INFO mapreduce.Job:  map 100% reduce 0%
# 2026-04-10 20:37:15,473 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local771269508_0001_m_000000_0 decomp: 1237274 len: 1237278 to MEMORY
# 2026-04-10 20:37:15,489 INFO reduce.InMemoryMapOutput: Read 1237274 bytes from map-output for attempt_local771269508_0001_m_000000_0
# 2026-04-10 20:37:15,529 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 1237274, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->1237274
# 2026-04-10 20:37:15,548 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2026-04-10 20:37:15,552 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:15,556 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2026-04-10 20:37:15,591 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:37:15,621 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1237270 bytes
# 2026-04-10 20:37:15,858 INFO reduce.MergeManagerImpl: Merged 1 segments, 1237274 bytes to disk to satisfy reduce memory limit
# 2026-04-10 20:37:15,866 INFO reduce.MergeManagerImpl: Merging 1 files, 1237278 bytes from disk
# 2026-04-10 20:37:15,868 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2026-04-10 20:37:15,868 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:37:15,871 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 1237270 bytes
# 2026-04-10 20:37:15,872 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:15,881 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./reduce.sh]
# 2026-04-10 20:37:15,892 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:37:15,893 INFO Configuration.deprecation: mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2026-04-10 20:37:15,898 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:37:15,899 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:37:15,903 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:37:15,907 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:37:15,907 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:37:15,908 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:37:15,912 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:37:15,913 INFO Configuration.deprecation: mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2026-04-10 20:37:15,913 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:37:15,961 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:15,961 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:15,967 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:15,980 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:16,025 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:16,048 INFO streaming.PipeMapRed: Records R/W=16807/1
# 2026-04-10 20:37:18,609 INFO streaming.PipeMapRed: R/W/S=100000/9011/0 in:50000=100000/2 [rec/s] out:4506=9013/2 [rec/s]
# 2026-04-10 20:37:19,986 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:37:19,987 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:37:19,988 INFO mapred.Task: Task:attempt_local771269508_0001_r_000000_0 is done. And is in the process of committing
# 2026-04-10 20:37:19,991 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:19,991 INFO mapred.Task: Task attempt_local771269508_0001_r_000000_0 is allowed to commit now
# 2026-04-10 20:37:19,994 INFO output.FileOutputCommitter: Saved output of task 'attempt_local771269508_0001_r_000000_0' to file:/content/wordcount/output
# 2026-04-10 20:37:19,995 INFO mapred.LocalJobRunner: Records R/W=16807/1 > reduce
# 2026-04-10 20:37:19,996 INFO mapred.Task: Task 'attempt_local771269508_0001_r_000000_0' done.
# 2026-04-10 20:37:19,996 INFO mapred.Task: Final Counters for attempt_local771269508_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=3219687
# 		FILE: Number of bytes written=3370099
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=14160
# 		Reduce shuffle bytes=1237278
# 		Reduce input records=127377
# 		Reduce output records=14160
# 		Spilled Records=127377
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=41
# 		Total committed heap usage (bytes)=125829120
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=158577
# 2026-04-10 20:37:19,997 INFO mapred.LocalJobRunner: Finishing task: attempt_local771269508_0001_r_000000_0
# 2026-04-10 20:37:19,997 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2026-04-10 20:37:20,353 INFO mapreduce.Job:  map 100% reduce 100%
# 2026-04-10 20:37:20,354 INFO mapreduce.Job: Job job_local771269508_0001 completed successfully
# 2026-04-10 20:37:20,371 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=3964786
# 		FILE: Number of bytes written=5344343
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=14537
# 		Map output records=127377
# 		Map output bytes=982518
# 		Map output materialized bytes=1237278
# 		Input split bytes=81
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=14160
# 		Reduce shuffle bytes=1237278
# 		Reduce input records=127377
# 		Reduce output records=14160
# 		Spilled Records=254754
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=54
# 		Total committed heap usage (bytes)=406847488
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=743407
# 	File Output Format Counters
# 		Bytes Written=158577
# 2026-04-10 20:37:20,374 INFO streaming.StreamJob: Output directory: wordcount/output

# %% [markdown]
# Check the output on HDFS

# %%
# !hdfs dfs -ls wordcount/output
# Out:
# Found 2 items
# -rw-r--r--   1 root root          0 2026-04-10 20:37 wordcount/output/_SUCCESS
# -rw-r--r--   1 root root     157337 2026-04-10 20:37 wordcount/output/part-00000

# %% [markdown]
# This job took a few seconds and this is quite some time for such a small file (4KB). This is due to the overhead of distributing the data and running the Hadoop framework.
# The advantage of Hadoop can be appreciated only for large datasets.

# %%
# !hdfs dfs -cat wordcount/output/part-00000|head
# Out:
# &	1
# (By	1
# (I	1
# (Lady	1
# (affection	1
# (an	1
# (and	3
# (arising	1
# (by-the-bye,	1
# (for	4
# cat: Unable to write to output stream.

# %% [markdown]
# ### Sort the output with `sort` <a name="sortoutput"></a>
#
# We've obtained a list of tokens that appear in the file followed by their frequencies.
#
# The output of the reducer is sorted by key (the word) because that's the ordering that the reducer becomes from the mapper. If we're interested in sorting the data by frequency, we can use the Unix `sort` command (with the options `k2`, `n`, `r` respectively "by field 2", "numeric", "reverse").

# %%
# !hdfs dfs -cat wordcount/output/part-00000|sort -k2nr|head
# Out:
# the	4340
# to	4203
# of	3788
# and	3376
# a	1965
# her	1905
# in	1865
# was	1814
# I	1764
# that	1446

# %% [markdown]
# The most common word is the article "the".

# %% [markdown]
# ### Sort the output with another MapReduce job <a name="sortoutputMR"></a>
#
# If we wanted to sort the output of the reducer using the mapreduce framework, we could employ a simple trick: create a mapper that interchanges words with their frequency values. Since by construction mappers sort their output by key, we get the desired sorting as a side-effect.
#
# Call the new mapper `swap_keyval.sh`.

# %%
# %%writefile swap_keyval.sh
# #!/bin/bash
# # This script will read one line at a time and swap key/value
# # For instance, the line "word 100" will become "100 word"
#
# while read key val
# do
#  printf "%s\t%s\n" "$val" "$key"
# done
# Out:
# Overwriting swap_keyval.sh

# %% [markdown]
# We are going to run the swap mapper script on the output of the previous mapreduce job. Note that in the below cell we are not deleting the previous output but instead we're saving the output from the current job in a new folder `output_sorted`.
#
# Nice thing about running a job on the output of a preceding job is that we do not need to upload files to HDFS because the data is already on HDFS. Not so nice: writing data to disk at each step of a data transformation pipeline takes time and this can be costly for longer data pipelines. This is one of the shortcomings of MapReduce that are addressed by [Apache Spark](https://spark.apache.org/).

# %%
# %%bash
# hdfs dfs -rm -r wordcount/output2 2>/dev/null
# mapred streaming \
#   -file swap_keyval.sh \
#   -input wordcount/output \
#   -output wordcount/output2 \
#   -mapper swap_keyval.sh
# Out:
# Deleted wordcount/output2
# packageJobJar: [swap_keyval.sh] [] /tmp/streamjob6708569400332527865.jar tmpDir=null
# 2026-04-10 20:37:31,410 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 2026-04-10 20:37:32,577 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:37:32,855 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-04-10 20:37:32,882 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-04-10 20:37:33,291 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local481836619_0001
# 2026-04-10 20:37:33,294 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-04-10 20:37:33,770 INFO mapred.LocalDistributedCacheManager: Localized file:/content/swap_keyval.sh as file:/tmp/hadoop-root/mapred/local/job_local481836619_0001_b959f0c2-74c4-4dad-befa-7970f898e5fb/swap_keyval.sh
# 2026-04-10 20:37:33,947 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2026-04-10 20:37:33,950 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2026-04-10 20:37:33,952 INFO mapreduce.Job: Running job: job_local481836619_0001
# 2026-04-10 20:37:33,956 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2026-04-10 20:37:33,972 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:33,980 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:34,057 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2026-04-10 20:37:34,064 INFO mapred.LocalJobRunner: Starting task: attempt_local481836619_0001_m_000000_0
# 2026-04-10 20:37:34,132 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:34,134 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:34,176 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:37:34,211 INFO mapred.MapTask: Processing split: file:/content/wordcount/output/part-00000:0+157337
# 2026-04-10 20:37:34,250 INFO mapred.MapTask: numReduceTasks: 1
# 2026-04-10 20:37:34,345 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2026-04-10 20:37:34,346 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2026-04-10 20:37:34,346 INFO mapred.MapTask: soft limit at 83886080
# 2026-04-10 20:37:34,347 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2026-04-10 20:37:34,347 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2026-04-10 20:37:34,352 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2026-04-10 20:37:34,361 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./swap_keyval.sh]
# 2026-04-10 20:37:34,367 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:37:34,369 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:37:34,370 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2026-04-10 20:37:34,370 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2026-04-10 20:37:34,371 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:37:34,372 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:37:34,374 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2026-04-10 20:37:34,375 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:37:34,375 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:37:34,376 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:37:34,377 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:37:34,378 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:37:34,437 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:34,440 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:34,441 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:34,466 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:34,500 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:34,512 INFO streaming.PipeMapRed: Records R/W=11773/1
# 2026-04-10 20:37:34,974 INFO mapreduce.Job: Job job_local481836619_0001 running in uber mode : false
# 2026-04-10 20:37:34,981 INFO mapreduce.Job:  map 0% reduce 0%
# 2026-04-10 20:37:35,061 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:37:35,062 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:37:35,069 INFO mapred.LocalJobRunner:
# 2026-04-10 20:37:35,072 INFO mapred.MapTask: Starting flush of map output
# 2026-04-10 20:37:35,074 INFO mapred.MapTask: Spilling map output
# 2026-04-10 20:37:35,074 INFO mapred.MapTask: bufstart = 0; bufend = 157337; bufvoid = 104857600
# 2026-04-10 20:37:35,083 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26157760(104631040); length = 56637/6553600
# 2026-04-10 20:37:35,191 INFO mapred.MapTask: Finished spill 0
# 2026-04-10 20:37:35,209 INFO mapred.Task: Task:attempt_local481836619_0001_m_000000_0 is done. And is in the process of committing
# 2026-04-10 20:37:35,213 INFO mapred.LocalJobRunner: Records R/W=11773/1
# 2026-04-10 20:37:35,213 INFO mapred.Task: Task 'attempt_local481836619_0001_m_000000_0' done.
# 2026-04-10 20:37:35,224 INFO mapred.Task: Final Counters for attempt_local481836619_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=159218
# 		FILE: Number of bytes written=919692
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=14160
# 		Map output records=14160
# 		Map output bytes=157337
# 		Map output materialized bytes=185663
# 		Input split bytes=93
# 		Combine input records=0
# 		Spilled Records=14160
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=291504128
# 	File Input Format Counters
# 		Bytes Read=158581
# 2026-04-10 20:37:35,225 INFO mapred.LocalJobRunner: Finishing task: attempt_local481836619_0001_m_000000_0
# 2026-04-10 20:37:35,226 INFO mapred.LocalJobRunner: map task executor complete.
# 2026-04-10 20:37:35,234 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2026-04-10 20:37:35,235 INFO mapred.LocalJobRunner: Starting task: attempt_local481836619_0001_r_000000_0
# 2026-04-10 20:37:35,249 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:35,249 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:35,250 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:37:35,257 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@5f0a66b9
# 2026-04-10 20:37:35,259 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:37:35,289 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2026-04-10 20:37:35,297 INFO reduce.EventFetcher: attempt_local481836619_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2026-04-10 20:37:35,372 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local481836619_0001_m_000000_0 decomp: 185659 len: 185663 to MEMORY
# 2026-04-10 20:37:35,383 INFO reduce.InMemoryMapOutput: Read 185659 bytes from map-output for attempt_local481836619_0001_m_000000_0
# 2026-04-10 20:37:35,391 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 185659, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->185659
# 2026-04-10 20:37:35,434 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2026-04-10 20:37:35,436 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:35,438 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2026-04-10 20:37:35,451 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:37:35,474 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 185655 bytes
# 2026-04-10 20:37:35,514 INFO reduce.MergeManagerImpl: Merged 1 segments, 185659 bytes to disk to satisfy reduce memory limit
# 2026-04-10 20:37:35,518 INFO reduce.MergeManagerImpl: Merging 1 files, 185663 bytes from disk
# 2026-04-10 20:37:35,520 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2026-04-10 20:37:35,520 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:37:35,522 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 185655 bytes
# 2026-04-10 20:37:35,523 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:35,637 INFO mapred.Task: Task:attempt_local481836619_0001_r_000000_0 is done. And is in the process of committing
# 2026-04-10 20:37:35,639 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:35,640 INFO mapred.Task: Task attempt_local481836619_0001_r_000000_0 is allowed to commit now
# 2026-04-10 20:37:35,642 INFO output.FileOutputCommitter: Saved output of task 'attempt_local481836619_0001_r_000000_0' to file:/content/wordcount/output2
# 2026-04-10 20:37:35,643 INFO mapred.LocalJobRunner: reduce > reduce
# 2026-04-10 20:37:35,643 INFO mapred.Task: Task 'attempt_local481836619_0001_r_000000_0' done.
# 2026-04-10 20:37:35,644 INFO mapred.Task: Final Counters for attempt_local481836619_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=530576
# 		FILE: Number of bytes written=1263932
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=217
# 		Reduce shuffle bytes=185663
# 		Reduce input records=14160
# 		Reduce output records=14160
# 		Spilled Records=14160
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=17
# 		Total committed heap usage (bytes)=119537664
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=158577
# 2026-04-10 20:37:35,645 INFO mapred.LocalJobRunner: Finishing task: attempt_local481836619_0001_r_000000_0
# 2026-04-10 20:37:35,645 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2026-04-10 20:37:35,988 INFO mapreduce.Job:  map 100% reduce 100%
# 2026-04-10 20:37:35,989 INFO mapreduce.Job: Job job_local481836619_0001 completed successfully
# 2026-04-10 20:37:35,999 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=689794
# 		FILE: Number of bytes written=2183624
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=14160
# 		Map output records=14160
# 		Map output bytes=157337
# 		Map output materialized bytes=185663
# 		Input split bytes=93
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=217
# 		Reduce shuffle bytes=185663
# 		Reduce input records=14160
# 		Reduce output records=14160
# 		Spilled Records=28320
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=17
# 		Total committed heap usage (bytes)=411041792
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=158581
# 	File Output Format Counters
# 		Bytes Written=158577
# 2026-04-10 20:37:35,999 INFO streaming.StreamJob: Output directory: wordcount/output2

# %% [markdown]
# Check the output on HDFS

# %%
# !hdfs dfs -ls wordcount/output2
# Out:
# Found 2 items
# -rw-r--r--   1 root root          0 2026-04-10 20:37 wordcount/output2/_SUCCESS
# -rw-r--r--   1 root root     157337 2026-04-10 20:37 wordcount/output2/part-00000

# %%
# !hdfs dfs -cat wordcount/output2/part-00000|head
# Out:
# 1	friends--to
# 1	friendship,
# 1	friendship,”
# 1	friends’
# 1	frighten
# 1	frightened.
# 1	gentle.
# 1	frigid
# 1	frisks,
# 1	genteel
# cat: Unable to write to output stream.

# %% [markdown]
# Mapper uses by default ascending order to sort by key. We could have changed that with an option but for now let's look at the end of the file.

# %%
# !hdfs dfs -cat wordcount/output2/part-00000|tail
# Out:
# 93	wish
# 93	her.
# 947	you
# 95	felt
# 97	last
# 97	hope
# 97	thought
# 98	quite
# 980	it
# 99	out

# %% [markdown]
# ### Configure sort with `KeyFieldBasedComparator` <a name="KeyFieldBasedComparator"></a>
#
# In general, we can determine how mappers are going to sort their output by configuring the comparator directive to use the special class [`KeyFieldBasedComparator`](https://hadoop.apache.org/docs/current/api/org/apache/hadoop/mapreduce/lib/partition/KeyFieldBasedComparator.html)
# <html><pre>-D mapreduce.job.output.key.comparator.class=\
#     org.apache.hadoop.mapred.lib.KeyFieldBasedComparator</pre></html>
#
# This class has some options similar to the Unix `sort`(`-n` to sort numerically, `-r` for reverse sorting, `-k pos1[,pos2]` for specifying fields to sort by).
#
# Let us see the comparator in action on our data to get the desired result. Note that this time we are removing `output2` because we're running the second mapreduce job again.

# %%
# %%bash
# hdfs dfs -rmr wordcount/output2 2>/dev/null
# comparator_class=org.apache.hadoop.mapred.lib.KeyFieldBasedComparator
# mapred streaming \
#   -D mapreduce.job.output.key.comparator.class=$comparator_class \
#   -D mapreduce.partition.keycomparator.options=-nr \
#   -file swap_keyval.sh \
#   -input wordcount/output \
#   -output wordcount/output2 \
#   -mapper swap_keyval.sh
# Out:
# Deleted wordcount/output2
# packageJobJar: [swap_keyval.sh] [] /tmp/streamjob14718982094114965996.jar tmpDir=null
# 2026-04-10 20:37:46,816 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# 2026-04-10 20:37:47,949 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:37:48,210 INFO mapred.FileInputFormat: Total input files to process : 1
# 2026-04-10 20:37:48,236 INFO mapreduce.JobSubmitter: number of splits:1
# 2026-04-10 20:37:48,552 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local975429258_0001
# 2026-04-10 20:37:48,554 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2026-04-10 20:37:48,984 INFO mapred.LocalDistributedCacheManager: Localized file:/content/swap_keyval.sh as file:/tmp/hadoop-root/mapred/local/job_local975429258_0001_f17b13cc-9ad3-4db6-8bcf-d08ceeb39f14/swap_keyval.sh
# 2026-04-10 20:37:49,117 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 2026-04-10 20:37:49,118 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2026-04-10 20:37:49,120 INFO mapreduce.Job: Running job: job_local975429258_0001
# 2026-04-10 20:37:49,123 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 2026-04-10 20:37:49,137 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:49,140 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:49,208 INFO mapred.LocalJobRunner: Waiting for map tasks
# 2026-04-10 20:37:49,215 INFO mapred.LocalJobRunner: Starting task: attempt_local975429258_0001_m_000000_0
# 2026-04-10 20:37:49,290 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:49,290 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:49,316 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:37:49,332 INFO mapred.MapTask: Processing split: file:/content/wordcount/output/part-00000:0+157337
# 2026-04-10 20:37:49,370 INFO mapred.MapTask: numReduceTasks: 1
# 2026-04-10 20:37:49,484 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 2026-04-10 20:37:49,485 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 2026-04-10 20:37:49,485 INFO mapred.MapTask: soft limit at 83886080
# 2026-04-10 20:37:49,485 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 2026-04-10 20:37:49,486 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 2026-04-10 20:37:49,496 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2026-04-10 20:37:49,507 INFO streaming.PipeMapRed: PipeMapRed exec [/content/./swap_keyval.sh]
# 2026-04-10 20:37:49,518 INFO Configuration.deprecation: mapred.work.output.dir is deprecated. Instead, use mapreduce.task.output.dir
# 2026-04-10 20:37:49,530 INFO Configuration.deprecation: mapred.local.dir is deprecated. Instead, use mapreduce.cluster.local.dir
# 2026-04-10 20:37:49,531 INFO Configuration.deprecation: map.input.file is deprecated. Instead, use mapreduce.map.input.file
# 2026-04-10 20:37:49,533 INFO Configuration.deprecation: map.input.length is deprecated. Instead, use mapreduce.map.input.length
# 2026-04-10 20:37:49,534 INFO Configuration.deprecation: mapred.job.id is deprecated. Instead, use mapreduce.job.id
# 2026-04-10 20:37:49,534 INFO Configuration.deprecation: mapred.task.partition is deprecated. Instead, use mapreduce.task.partition
# 2026-04-10 20:37:49,538 INFO Configuration.deprecation: map.input.start is deprecated. Instead, use mapreduce.map.input.start
# 2026-04-10 20:37:49,539 INFO Configuration.deprecation: mapred.task.is.map is deprecated. Instead, use mapreduce.task.ismap
# 2026-04-10 20:37:49,541 INFO Configuration.deprecation: mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2026-04-10 20:37:49,542 INFO Configuration.deprecation: mapred.tip.id is deprecated. Instead, use mapreduce.task.id
# 2026-04-10 20:37:49,543 INFO Configuration.deprecation: mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2026-04-10 20:37:49,546 INFO Configuration.deprecation: user.name is deprecated. Instead, use mapreduce.job.user.name
# 2026-04-10 20:37:49,588 INFO streaming.PipeMapRed: R/W/S=1/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:49,588 INFO streaming.PipeMapRed: R/W/S=10/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:49,590 INFO streaming.PipeMapRed: R/W/S=100/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:49,601 INFO streaming.PipeMapRed: R/W/S=1000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:49,641 INFO streaming.PipeMapRed: R/W/S=10000/0/0 in:NA [rec/s] out:NA [rec/s]
# 2026-04-10 20:37:49,649 INFO streaming.PipeMapRed: Records R/W=11773/1
# 2026-04-10 20:37:50,090 INFO streaming.PipeMapRed: MRErrorThread done
# 2026-04-10 20:37:50,091 INFO streaming.PipeMapRed: mapRedFinished
# 2026-04-10 20:37:50,095 INFO mapred.LocalJobRunner:
# 2026-04-10 20:37:50,095 INFO mapred.MapTask: Starting flush of map output
# 2026-04-10 20:37:50,096 INFO mapred.MapTask: Spilling map output
# 2026-04-10 20:37:50,096 INFO mapred.MapTask: bufstart = 0; bufend = 157337; bufvoid = 104857600
# 2026-04-10 20:37:50,104 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26157760(104631040); length = 56637/6553600
# 2026-04-10 20:37:50,139 INFO mapreduce.Job: Job job_local975429258_0001 running in uber mode : false
# 2026-04-10 20:37:50,146 INFO mapreduce.Job:  map 0% reduce 0%
# 2026-04-10 20:37:50,217 INFO mapred.MapTask: Finished spill 0
# 2026-04-10 20:37:50,237 INFO mapred.Task: Task:attempt_local975429258_0001_m_000000_0 is done. And is in the process of committing
# 2026-04-10 20:37:50,244 INFO mapred.LocalJobRunner: Records R/W=11773/1
# 2026-04-10 20:37:50,244 INFO mapred.Task: Task 'attempt_local975429258_0001_m_000000_0' done.
# 2026-04-10 20:37:50,257 INFO mapred.Task: Final Counters for attempt_local975429258_0001_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=159218
# 		FILE: Number of bytes written=920594
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=14160
# 		Map output records=14160
# 		Map output bytes=157337
# 		Map output materialized bytes=185663
# 		Input split bytes=93
# 		Combine input records=0
# 		Spilled Records=14160
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=306184192
# 	File Input Format Counters
# 		Bytes Read=158581
# 2026-04-10 20:37:50,259 INFO mapred.LocalJobRunner: Finishing task: attempt_local975429258_0001_m_000000_0
# 2026-04-10 20:37:50,259 INFO mapred.LocalJobRunner: map task executor complete.
# 2026-04-10 20:37:50,265 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 2026-04-10 20:37:50,266 INFO mapred.LocalJobRunner: Starting task: attempt_local975429258_0001_r_000000_0
# 2026-04-10 20:37:50,278 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 2
# 2026-04-10 20:37:50,278 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2026-04-10 20:37:50,278 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 2026-04-10 20:37:50,283 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@457ba6da
# 2026-04-10 20:37:50,286 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2026-04-10 20:37:50,329 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=2381106432, maxSingleShuffleLimit=595276608, mergeThreshold=1571530368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2026-04-10 20:37:50,335 INFO reduce.EventFetcher: attempt_local975429258_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2026-04-10 20:37:50,402 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local975429258_0001_m_000000_0 decomp: 185659 len: 185663 to MEMORY
# 2026-04-10 20:37:50,413 INFO reduce.InMemoryMapOutput: Read 185659 bytes from map-output for attempt_local975429258_0001_m_000000_0
# 2026-04-10 20:37:50,423 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 185659, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->185659
# 2026-04-10 20:37:50,432 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 2026-04-10 20:37:50,434 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:50,435 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2026-04-10 20:37:50,446 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:37:50,453 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 185652 bytes
# 2026-04-10 20:37:50,523 INFO reduce.MergeManagerImpl: Merged 1 segments, 185659 bytes to disk to satisfy reduce memory limit
# 2026-04-10 20:37:50,549 INFO reduce.MergeManagerImpl: Merging 1 files, 185663 bytes from disk
# 2026-04-10 20:37:50,550 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 2026-04-10 20:37:50,550 INFO mapred.Merger: Merging 1 sorted segments
# 2026-04-10 20:37:50,560 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 185652 bytes
# 2026-04-10 20:37:50,562 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:50,662 INFO mapred.Task: Task:attempt_local975429258_0001_r_000000_0 is done. And is in the process of committing
# 2026-04-10 20:37:50,664 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 2026-04-10 20:37:50,665 INFO mapred.Task: Task attempt_local975429258_0001_r_000000_0 is allowed to commit now
# 2026-04-10 20:37:50,668 INFO output.FileOutputCommitter: Saved output of task 'attempt_local975429258_0001_r_000000_0' to file:/content/wordcount/output2
# 2026-04-10 20:37:50,669 INFO mapred.LocalJobRunner: reduce > reduce
# 2026-04-10 20:37:50,669 INFO mapred.Task: Task 'attempt_local975429258_0001_r_000000_0' done.
# 2026-04-10 20:37:50,670 INFO mapred.Task: Final Counters for attempt_local975429258_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=530576
# 		FILE: Number of bytes written=1264834
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=217
# 		Reduce shuffle bytes=185663
# 		Reduce input records=14160
# 		Reduce output records=14160
# 		Spilled Records=14160
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=113246208
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=158577
# 2026-04-10 20:37:50,671 INFO mapred.LocalJobRunner: Finishing task: attempt_local975429258_0001_r_000000_0
# 2026-04-10 20:37:50,671 INFO mapred.LocalJobRunner: reduce task executor complete.
# 2026-04-10 20:37:51,158 INFO mapreduce.Job:  map 100% reduce 100%
# 2026-04-10 20:37:51,159 INFO mapreduce.Job: Job job_local975429258_0001 completed successfully
# 2026-04-10 20:37:51,170 INFO mapreduce.Job: Counters: 30
# 	File System Counters
# 		FILE: Number of bytes read=689794
# 		FILE: Number of bytes written=2185428
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=14160
# 		Map output records=14160
# 		Map output bytes=157337
# 		Map output materialized bytes=185663
# 		Input split bytes=93
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=217
# 		Reduce shuffle bytes=185663
# 		Reduce input records=14160
# 		Reduce output records=14160
# 		Spilled Records=28320
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=20
# 		Total committed heap usage (bytes)=419430400
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=158581
# 	File Output Format Counters
# 		Bytes Written=158577
# 2026-04-10 20:37:51,170 INFO streaming.StreamJob: Output directory: wordcount/output2

# %%
# !hdfs dfs -ls wordcount/output2
# Out:
# Found 2 items
# -rw-r--r--   1 root root          0 2026-04-10 20:37 wordcount/output2/_SUCCESS
# -rw-r--r--   1 root root     157337 2026-04-10 20:37 wordcount/output2/part-00000

# %%
# !hdfs dfs -cat wordcount/output2/part-00000|head
# Out:
# 4340	the
# 4203	to
# 3788	of
# 3376	and
# 1965	a
# 1905	her
# 1865	in
# 1814	was
# 1764	I
# 1446	that
# cat: Unable to write to output stream.

# %% [markdown]
# Now we get the output in the desired order.

# %% [markdown]
# ### Specifying Configuration Variables with the -D Option <a name="configuration_variables"></a>
#
# With the `-D` option it is possible to override options set in the default configuration file [`mapred_default.xml`](https://hadoop.apache.org/docs/current/hadoop-mapreduce-client/hadoop-mapreduce-client-core/mapred-default.xml)
# (see the [Apache Hadoop documentation](https://hadoop.apache.org/docs/current/hadoop-streaming/HadoopStreaming.html#Specifying_Configuration_Variables_with_the_-D_Option)).
#
# One option that might come handy when dealing with out-of-memory issues in the sorting phase is the size in MB of the memory reserved for sorting `mapreduce.task.io.sort.mb`:
#  <html>
#     <pre>-D mapreduce.task.io.sort.mb=512</pre>
#  </html>
#
#  **Note:** the maximum value for `mapreduce.task.io.sort.mb` is 2047.

# %% [markdown]
# ## What is word count useful for? <a name="wordcount"></a>
# Counting the frequencies of words is a fundamental operation in many areas, particularly in natural language processing (NLP) and information retrieval. Here's a more detailed look at its utility:
#
# *   **Indexing and Search Engines:** Word counts are at the very basis of how search engines work. When a search engine indexes documents, it essentially counts the occurrences of each word. This information, along with other factors, helps determine the relevance of a document to a user's search query.
#
# *   **Text Analysis and NLP:**
#     *   **Keyword Extraction:** Identifying the most frequent words can highlight key topics or themes within a document or collection of documents.
#     *   **Sentiment Analysis:** While basic word count isn't direct sentiment analysis, it's a building block. Analyzing the frequency of positive or negative words can give a preliminary indication of sentiment.
#     *   **Text Summarization:** High-frequency words (excluding common stop words) are often crucial for understanding the main points of a text, which can aid in automatic summarization.
#     *   **Topic Modeling:** Word counts are inputs to more advanced algorithms like Latent Dirichlet Allocation (LDA) for discovering abstract 'topics' within a collection of documents.
#     *   **Linguistic Research:** Linguists use word frequencies to study language patterns, vocabulary usage, and stylistic characteristics of authors or genres.
#
# *   **Data Cleaning and Preprocessing:** Before more complex NLP tasks, word count can help identify noisy data (e.g., unusual characters, misspellings) or frequent, uninformative words (stop words like 'the', 'a', 'is') that might need to be removed.
#
# *   **Market Research and Trends:** By counting words in social media posts, news articles, or customer reviews, businesses can identify popular products, emerging trends, or common complaints.
